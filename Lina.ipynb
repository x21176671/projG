# %%
import pymongo
import pandas as pd
from pymongo import MongoClient
import json
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime
import statistics
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.api  import VAR
from statsmodels.tsa.stattools import grangercausalitytests, adfuller
from statsmodels.tsa.statespace.varmax import VARMAX

import warnings
warnings.filterwarnings('ignore')

# %%
#MongoDB creation

client = MongoClient()

# %%
# connect to a Mongo client. This connects on the default host and port)
from pymongo import MongoClient
client = MongoClient('mongodb://192.168.56.30:27017')

# %%
# creating database 
db = client["price_index"]

# %%
#add a collection to that database
collection = db['data_collection']

# %%
##To insert a single document into a collection##
posts = db.posts
post_id = posts.insert_one(post).inserted_id
post_id

# %%
##Retrieving document
import pprint
pprint.pprint(posts.find_one())
# Out:
# {'Cereals and products': 107.5,
#  'Clothing': 106.5,
#  'Clothing and footwear': 106.4,
#  'Education': 103.8,
#  'Egg': 108.1,
#  'Food and beverages': 105.5,
#  'Footwear': 105.8,
#  'Fruits': 103.9,
#  'Fuel and light': 105.5,
#  'General index': 105.1,
#  'Health': 104,
#  'Household goods and services': 104.8,
#  'Housing': '',
#  'Meat and fish': 106.3,
#  'Milk and products': 104.9,
#  'Miscellaneous': 104,
#  'Month': 'January',
#  'Non-alcoholic beverages': 104.8,
#  'Oils and fats': 106.1,
#  'Pan, tobacco and intoxicants': 105.1,
#  'Personal care and effects': 104.7,
#  'Prepared meals, snacks, sweets etc.': 106.7,
#  'Pulses and products': 106.1,
#  'Recreation and amusement': 103.4,
#  'Sector': 'Rural',
#  'Spices': 103.1,
#  'Sugar and Confectionery': 106.8,
#  'Transport and communication': 103.3,
#  'Vegetables': 101.9,
#  'Year': 2013,
#  '_id': ObjectId('625d4dc34d368beb7897d887')}

# %%
##count documents
posts.count_documents({})
# Out:
# 129

# %%
##conect collection with database
data = db.posts

# %%
##convert collection to dataframe
data = pd.DataFrame(list(data.find()))

# %%
data
# Out:
#                           _id       Sector  Year     Month  \
# 0    625d4dc34d368beb7897d887        Rural  2013   January
# 1    625d4dc64d368beb7897d888        Urban  2013   January
# 2    625d4dc74d368beb7897d889  Rural+Urban  2013   January
# 3    625d4dc74d368beb7897d88a        Rural  2013  February
# 4    625d4dc84d368beb7897d88b        Urban  2013  February
# ..                        ...          ...   ...       ...
# 124  625d4e2a4d368beb7897d903        Urban  2016      June
# 125  625d4e2b4d368beb7897d904  Rural+Urban  2016      June
# 126  625d4e2b4d368beb7897d905        Rural  2016      July
# 127  625d4e2c4d368beb7897d906        Urban  2016      July
# 128  625d4e2c4d368beb7897d907  Rural+Urban  2016      July
#
#      Cereals and products  Meat and fish    Egg  Milk and products  \
# 0                   107.5          106.3  108.1              104.9
# 1                   110.5          109.1  113.0              103.6
# 2                   108.4          107.3  110.0              104.4
# 3                   109.2          108.7  110.2              105.4
# 4                   112.9          112.9  116.9              104.0
# ..                    ...            ...    ...                ...
# 124                 125.9          143.9  130.9              131.0
# 125                 127.7          140.5  128.3              132.6
# 126                 129.3          139.5  129.6              134.5
# 127                 126.8          144.2  136.6              131.8
# 128                 128.5          141.2  132.3              133.5
#
#      Oils and fats  Fruits  ...  Housing  Fuel and light  \
# 0            106.1   103.9  ...                    105.5
# 1            103.4   102.3  ...    100.3           105.4
# 2            105.1   103.2  ...    100.3           105.5
# 3            106.7   104.0  ...                    106.2
# 4            103.5   103.1  ...    100.4           105.7
# ..             ...     ...  ...      ...             ...
# 124          110.2   135.5  ...    125.5           115.5
# 125          115.5   136.5  ...    125.5           123.3
# 126          119.5   138.5  ...       NA           128.2
# 127          111.0   137.0  ...    126.4           115.5
# 128          116.4   137.8  ...    126.4           123.4
#
#      Household goods and services  Health  Transport and communication  \
# 0                           104.8   104.0                        103.3
# 1                           104.8   104.1                        103.2
# 2                           104.8   104.0                        103.2
# 3                           105.2   104.4                        103.9
# 4                           105.2   104.7                        104.4
# ..                            ...     ...                          ...
# 124                         123.2   120.6                        112.3
# 125                         126.4   124.1                        114.2
# 126                         130.0   126.7                        116.4
# 127                         123.5   120.9                        111.7
# 128                         126.9   124.5                        113.9
#
#      Recreation and amusement  Education  Personal care and effects  \
# 0                       103.4      103.8                      104.7
# 1                       102.9      103.5                      104.3
# 2                       103.1      103.6                      104.5
# 3                       104.0      104.1                      104.6
# 4                       103.3      103.7                      104.3
# ..                        ...        ...                        ...
# 124                     119.9      129.3                      118.8
# 125                     121.7      129.7                      119.4
# 126                     125.2      130.8                      120.9
# 127                     120.3      130.8                      120.0
# 128                     122.4      130.8                      120.5
#
#      Miscellaneous  General index
# 0            104.0          105.1
# 1            103.7          104.0
# 2            103.9          104.6
# 3            104.4          105.8
# 4            104.3          104.7
# ..             ...            ...
# 124          119.6          128.1
# 125          121.5          130.1
# 126          123.8          133.0
# 127          119.9          129.0
# 128          121.9          131.1
#
# [129 rows x 31 columns]

# %%
#DATA PREPROCEESING
#Data cleaning, detecting missing value
#sum of missing values
pd.isnull(data).sum().sum()

# %%
#detect a list of missing values
missing_vals = ["NA", "", None, np.NaN]
missing = data.isin(missing_vals)
missing.head()
# Out:
#      _id  Sector   Year  Month  Cereals and products  Meat and fish    Egg  \
# 0  False   False  False  False                 False          False  False
# 1  False   False  False  False                 False          False  False
# 2  False   False  False  False                 False          False  False
# 3  False   False  False  False                 False          False  False
# 4  False   False  False  False                 False          False  False
#
#    Milk and products  Oils and fats  Fruits  ...  Housing  Fuel and light  \
# 0              False          False   False  ...     True           False
# 1              False          False   False  ...    False           False
# 2              False          False   False  ...    False           False
# 3              False          False   False  ...     True           False
# 4              False          False   False  ...    False           False
#
#    Household goods and services  Health  Transport and communication  \
# 0                         False   False                        False
# 1                         False   False                        False
# 2                         False   False                        False
# 3                         False   False                        False
# 4                         False   False                        False
#
#    Recreation and amusement  Education  Personal care and effects  \
# 0                     False      False                      False
# 1                     False      False                      False
# 2                     False      False                      False
# 3                     False      False                      False
# 4                     False      False                      False
#
#    Miscellaneous  General index
# 0          False          False
# 1          False          False
# 2          False          False
# 3          False          False
# 4          False          False
#
# [5 rows x 31 columns]

# %%
#column Housing missing values
print(data['Housing'])
# Out:
# 0
# 1      100.3
# 2      100.3
# 3
# 4      100.4
#        ...
# 124    125.5
# 125    125.5
# 126       NA
# 127    126.4
# 128    126.4
# Name: Housing, Length: 129, dtype: object

# %%
#convert column housing type 
data["Housing"] = pd.to_numeric(data.Housing, errors='coerce')

# %%
# Box plot and distribution plot for decising whether to use mean, media or mode
# Box plot 
sns.boxplot(data.Housing)
# Out:
# <AxesSubplot:xlabel='Housing'>

# %%
sns.displot(data.Housing)

# %%
# Replace Blank values with DataFrame.replace() methods.
data = data.replace(r'^\s*$', np.nan, regex=True)
#print(data['Housing'].dtype)

# %%
#replace missing value with mean
x = data["Housing"].mean()
data["Housing"].fillna(x, inplace = True)

# %%
#rename names of columns
data.rename(columns = {'Pulses and products':'Pulses_and_Products', 'Transport and communication':'Transport', 'Fuel and light': 'Fuel'}, inplace = True)

# %%
#Create dataframe for future analysis
data1 = pd.DataFrame([data.Year, data.Month, data.Housing, data.Clothing, data.Transport, data.Health, data.Pulses_and_Products, data.Fuel ]).transpose()

# %%
#Convert variable year 
data1['Year'].astype(float).astype('Int64')
# Out:
# 0      2013
# 1      2013
# 2      2013
# 3      2013
# 4      2013
#        ...
# 124    2016
# 125    2016
# 126    2016
# 127    2016
# 128    2016
# Name: Year, Length: 129, dtype: Int64

# %%
#create dictionary, change month names to numbers
mydict = {"January":"01","February":"02","March":"03","April":"04","May":"05","June":"06","July":"07","August":"08","September":"09","October":"10","November":"11","December":"12"}

# %%
#replace month names to month number
data1.Month = data1.Month.map(mydict)

# %%
#convertting date to appropriate format 
data1['Date'] = data1['Year'].astype(str) + '-' + data1['Month']

# %%
# add  a new "Date" column
data1['Date'] = pd.to_datetime(data1['Date'], format='%Y-%m')
data1
# Out:
#      Year Month     Housing Clothing Transport Health Pulses_and_Products  \
# 0    2013    01  115.383721    106.5     103.3  104.0               106.1
# 1    2013    01       100.3    105.9     103.2  104.1               105.8
# 2    2013    01       100.3    106.3     103.2  104.0               106.0
# 3    2013    02  115.383721    107.1     103.9  104.4               105.9
# 4    2013    02       100.4    106.6     104.4  104.7               104.1
# ..    ...   ...         ...      ...       ...    ...                 ...
# 124  2016    06       125.5    127.6     112.3  120.6               184.4
# 125  2016    06       125.5    132.9     114.2  124.1               174.3
# 126  2016    07  115.383721    137.2     116.4  126.7               171.8
# 127  2016    07       126.4    127.9     111.7  120.9               188.4
# 128  2016    07       126.4    133.5     113.9  124.5               177.4
#
#       Fuel       Date
# 0    105.5 2013-01-01
# 1    105.4 2013-01-01
# 2    105.5 2013-01-01
# 3    106.2 2013-02-01
# 4    105.7 2013-02-01
# ..     ...        ...
# 124  115.5 2016-06-01
# 125  123.3 2016-06-01
# 126  128.2 2016-07-01
# 127  115.5 2016-07-01
# 128  123.4 2016-07-01
#
# [129 rows x 9 columns]

# %%
#group data by years 
newdata = data1.groupby('Date', as_index = False).agg({'Pulses_and_Products': 'sum', 'Housing': 'sum', 'Clothing': 'sum', 'Transport': 'sum', 'Health': 'sum', 'Fuel': 'sum'})

# %%
# assign index Dae for dataframe
newdata.index = newdata.Date
del newdata['Date']
print(newdata.head())
# Out:
#            Pulses_and_Products     Housing Clothing Transport Health   Fuel
# Date
# 2013-01-01               317.9  315.983721    318.7     309.7  312.1  316.4
# 2013-02-01               315.3  316.183721    320.6     312.5  313.6  317.9
# 2013-03-01               314.2  316.183721    322.2     315.2  314.8  318.2
# 2013-04-01               315.6  316.383721    324.0     314.1  316.1  319.4
# 2013-05-01               317.1  316.383721    326.0     312.0  317.8  322.1

# %%
# TIME SERIES FORECASTING using Vector autoregression model(VAR)
#visualize variables

fig, axes = plt.subplots(nrows=3, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = newdata[newdata.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    
    ax.set_title(newdata.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines['top'].set_alpha(0)
    ax.tick_params (labelsize=4)
    
plt.tight_layout();

# %%
#Stionary Dickey-Fuller test 
#Pulses and Products
ad_fuller_result_1 =adfuller(newdata['Pulses_and_Products'])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
# Out:
# ADF Statistic: 0.2473265416118735
# p-value:0.9747945199950344

# %%
#diff
ad_fuller_result_1 =adfuller(newdata['Pulses_and_Products'].diff()[1:])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
# Out:
# ADF Statistic: -8.95655836406942
# p-value:8.44333263776967e-15

# %%
#Housing variable
ad_fuller_result_1 =adfuller(newdata['Housing'])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
#diff
ad_fuller_result_1 =adfuller(newdata['Housing'].diff()[1:])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
# Out:
# ADF Statistic: -10.517716358321582
# p-value:9.864735434641275e-19
# ADF Statistic: -10.759472449300342
# p-value:2.542595312397549e-19

# %%
#Clothing variable
ad_fuller_result_1 =adfuller(newdata['Clothing'])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
#diff
ad_fuller_result_1 =adfuller(newdata['Clothing'].diff()[1:])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
# Out:
# ADF Statistic: -12.267372833259104
# p-value:8.797724529062638e-23
# ADF Statistic: -10.879650790469283
# p-value:1.304615391467838e-19

# %%
#Transport variable
ad_fuller_result_1 =adfuller(newdata['Transport'])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
#diff
ad_fuller_result_1 =adfuller(newdata['Transport'].diff()[1:])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
# Out:
# ADF Statistic: -5.320262138608998
# p-value:4.970551898514679e-06
# ADF Statistic: -10.476223357924505
# p-value:1.2470391017391115e-18

# %%
#Health variable
ad_fuller_result_1 =adfuller(newdata['Health'])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
#diff
ad_fuller_result_1 =adfuller(newdata['Health'].diff()[1:])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
# Out:
# ADF Statistic: -9.148262320747797
# p-value:2.730402117310084e-15
# ADF Statistic: -10.788783673771338
# p-value:2.1597911333952598e-19

# %%
#Fuel variable
ad_fuller_result_1 =adfuller(newdata['Fuel'])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
#diff
ad_fuller_result_1 =adfuller(newdata['Fuel'].diff()[1:])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
# Out:
# ADF Statistic: -13.699478012271946
# p-value:1.29787809558337e-25
# ADF Statistic: -10.794971972369865
# p-value:2.0867261014639754e-19

# %%
#Stionary Dickey-Fuller test 
#Pulses and Products
ad_fuller_result_1 =adfuller(newdata['Pulses_and_Products'])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
#diff
ad_fuller_result_1 =adfuller(newdata['Pulses_and_Products'].diff()[1:])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
#Housing variable
ad_fuller_result_1 =adfuller(newdata['Housing'])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
#diff
ad_fuller_result_1 =adfuller(newdata['Housing'].diff()[1:])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
#Clothing variable
ad_fuller_result_1 =adfuller(newdata['Clothing'])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
#diff
ad_fuller_result_1 =adfuller(newdata['Clothing'].diff()[1:])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
#Transport variable
ad_fuller_result_1 =adfuller(newdata['Transport'])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
#diff
ad_fuller_result_1 =adfuller(newdata['Transport'].diff()[1:])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
#Health variable
ad_fuller_result_1 =adfuller(newdata['Health'])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
#diff
ad_fuller_result_1 =adfuller(newdata['Health'].diff()[1:])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
#Fuel variable
ad_fuller_result_1 =adfuller(newdata['Fuel'])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
#diff
ad_fuller_result_1 =adfuller(newdata['Fuel'].diff()[1:])
print (f'ADF Statistic: {ad_fuller_result_1[0]}')
print (f'p-value:{ad_fuller_result_1[1]}')
# Out:
# ADF Statistic: 0.2473265416118735
# p-value:0.9747945199950344
# ADF Statistic: -8.95655836406942
# p-value:8.44333263776967e-15
# ADF Statistic: -10.517716358321582
# p-value:9.864735434641275e-19
# ADF Statistic: -10.759472449300342
# p-value:2.542595312397549e-19
# ADF Statistic: -12.267372833259104
# p-value:8.797724529062638e-23
# ADF Statistic: -10.879650790469283
# p-value:1.304615391467838e-19
# ADF Statistic: -5.320262138608998
# p-value:4.970551898514679e-06
# ADF Statistic: -10.476223357924505
# p-value:1.2470391017391115e-18
# ADF Statistic: -9.148262320747797
# p-value:2.730402117310084e-15
# ADF Statistic: -10.788783673771338
# p-value:2.1597911333952598e-19
# ADF Statistic: -13.699478012271946
# p-value:1.29787809558337e-25
# ADF Statistic: -10.794971972369865
# p-value:2.0867261014639754e-19

# %%
#Checking correlation Granger Causality Test
print ('Housing causes Pulses_and_Products ?\n')
granger_1 = grangercausalitytests(newdata[['Pulses_and_Products', 'Housing']],4)

print ('Pulses_and_Product causes Housing?\n')
granger_1 = grangercausalitytests(newdata[['Housing','Pulses_and_Products' ]],4)

print ('Transport causes Clothing ?\n')
granger_1 = grangercausalitytests(newdata[['Clothing', 'Transport']],4)

print ('Clothing causes Transport?\n')
granger_1 = grangercausalitytests(newdata[['Transport','Clothing' ]],4)


print ('Fuel causes Health ?\n')
granger_1 = grangercausalitytests(newdata[['Health', 'Fuel']],4)

print ('Health causes Fuel?\n')
granger_1 = grangercausalitytests(newdata[['Fuel','Health' ]],4)
# Out:
# Housing causes Pulses_and_Products ?
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=14.8334 , p=0.0004  , df_denom=39, df_num=1
# ssr based chi2 test:   chi2=15.9744 , p=0.0001  , df=1
# likelihood ratio test: chi2=13.5380 , p=0.0002  , df=1
# parameter F test:         F=14.8334 , p=0.0004  , df_denom=39, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=7.5994  , p=0.0018  , df_denom=36, df_num=2
# ssr based chi2 test:   chi2=17.3097 , p=0.0002  , df=2
# likelihood ratio test: chi2=14.4400 , p=0.0007  , df=2
# parameter F test:         F=7.5994  , p=0.0018  , df_denom=36, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.9785  , p=0.0059  , df_denom=33, df_num=3
# ssr based chi2 test:   chi2=18.1037 , p=0.0004  , df=3
# likelihood ratio test: chi2=14.9340 , p=0.0019  , df=3
# parameter F test:         F=4.9785  , p=0.0059  , df_denom=33, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.6011  , p=0.0164  , df_denom=30, df_num=4
# ssr based chi2 test:   chi2=18.7255 , p=0.0009  , df=4
# likelihood ratio test: chi2=15.2934 , p=0.0041  , df=4
# parameter F test:         F=3.6011  , p=0.0164  , df_denom=30, df_num=4
# Pulses_and_Product causes Housing?
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=8.0649  , p=0.0071  , df_denom=39, df_num=1
# ssr based chi2 test:   chi2=8.6852  , p=0.0032  , df=1
# likelihood ratio test: chi2=7.8945  , p=0.0050  , df=1
# parameter F test:         F=8.0649  , p=0.0071  , df_denom=39, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.3904  , p=0.1060  , df_denom=36, df_num=2
# ssr based chi2 test:   chi2=5.4448  , p=0.0657  , df=2
# likelihood ratio test: chi2=5.1124  , p=0.0776  , df=2
# parameter F test:         F=2.3904  , p=0.1060  , df_denom=36, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0657  , p=0.3769  , df_denom=33, df_num=3
# ssr based chi2 test:   chi2=3.8752  , p=0.2753  , df=3
# likelihood ratio test: chi2=3.6988  , p=0.2959  , df=3
# parameter F test:         F=1.0657  , p=0.3769  , df_denom=33, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6106  , p=0.6582  , df_denom=30, df_num=4
# ssr based chi2 test:   chi2=3.1752  , p=0.5289  , df=4
# likelihood ratio test: chi2=3.0525  , p=0.5491  , df=4
# parameter F test:         F=0.6106  , p=0.6582  , df_denom=30, df_num=4
# Transport causes Clothing ?
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=24.3479 , p=0.0000  , df_denom=39, df_num=1
# ssr based chi2 test:   chi2=26.2208 , p=0.0000  , df=1
# likelihood ratio test: chi2=20.3733 , p=0.0000  , df=1
# parameter F test:         F=24.3479 , p=0.0000  , df_denom=39, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=8.0965  , p=0.0012  , df_denom=36, df_num=2
# ssr based chi2 test:   chi2=18.4421 , p=0.0001  , df=2
# likelihood ratio test: chi2=15.2286 , p=0.0005  , df=2
# parameter F test:         F=8.0965  , p=0.0012  , df_denom=36, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.8176  , p=0.0069  , df_denom=33, df_num=3
# ssr based chi2 test:   chi2=17.5187 , p=0.0006  , df=3
# likelihood ratio test: chi2=14.5292 , p=0.0023  , df=3
# parameter F test:         F=4.8176  , p=0.0069  , df_denom=33, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.7272  , p=0.0477  , df_denom=30, df_num=4
# ssr based chi2 test:   chi2=14.1815 , p=0.0067  , df=4
# likelihood ratio test: chi2=12.0958 , p=0.0167  , df=4
# parameter F test:         F=2.7272  , p=0.0477  , df_denom=30, df_num=4
# Clothing causes Transport?
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.7081  , p=0.0218  , df_denom=39, df_num=1
# ssr based chi2 test:   chi2=6.1472  , p=0.0132  , df=1
# likelihood ratio test: chi2=5.7370  , p=0.0166  , df=1
# parameter F test:         F=5.7081  , p=0.0218  , df_denom=39, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.0778  , p=0.0253  , df_denom=36, df_num=2
# ssr based chi2 test:   chi2=9.2884  , p=0.0096  , df=2
# likelihood ratio test: chi2=8.3723  , p=0.0152  , df=2
# parameter F test:         F=4.0778  , p=0.0253  , df_denom=36, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.2310  , p=0.0348  , df_denom=33, df_num=3
# ssr based chi2 test:   chi2=11.7490 , p=0.0083  , df=3
# likelihood ratio test: chi2=10.3010 , p=0.0162  , df=3
# parameter F test:         F=3.2310  , p=0.0348  , df_denom=33, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.0996  , p=0.1056  , df_denom=30, df_num=4
# ssr based chi2 test:   chi2=10.9181 , p=0.0275  , df=4
# likelihood ratio test: chi2=9.6261  , p=0.0472  , df=4
# parameter F test:         F=2.0996  , p=0.1056  , df_denom=30, df_num=4
# Fuel causes Health ?
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=12.9027 , p=0.0009  , df_denom=39, df_num=1
# ssr based chi2 test:   chi2=13.8952 , p=0.0002  , df=1
# likelihood ratio test: chi2=12.0040 , p=0.0005  , df=1
# parameter F test:         F=12.9027 , p=0.0009  , df_denom=39, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.6069  , p=0.0373  , df_denom=36, df_num=2
# ssr based chi2 test:   chi2=8.2158  , p=0.0164  , df=2
# likelihood ratio test: chi2=7.4883  , p=0.0237  , df=2
# parameter F test:         F=3.6069  , p=0.0373  , df_denom=36, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.5127  , p=0.2294  , df_denom=33, df_num=3
# ssr based chi2 test:   chi2=5.5008  , p=0.1386  , df=3
# likelihood ratio test: chi2=5.1540  , p=0.1609  , df=3
# parameter F test:         F=1.5127  , p=0.2294  , df_denom=33, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.1299  , p=0.3612  , df_denom=30, df_num=4
# ssr based chi2 test:   chi2=5.8752  , p=0.2087  , df=4
# likelihood ratio test: chi2=5.4726  , p=0.2421  , df=4
# parameter F test:         F=1.1299  , p=0.3612  , df_denom=30, df_num=4
# Health causes Fuel?
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=10.5065 , p=0.0024  , df_denom=39, df_num=1
# ssr based chi2 test:   chi2=11.3147 , p=0.0008  , df=1
# likelihood ratio test: chi2=10.0188 , p=0.0015  , df=1
# parameter F test:         F=10.5065 , p=0.0024  , df_denom=39, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.2181  , p=0.0518  , df_denom=36, df_num=2
# ssr based chi2 test:   chi2=7.3300  , p=0.0256  , df=2
# likelihood ratio test: chi2=6.7437  , p=0.0343  , df=2
# parameter F test:         F=3.2181  , p=0.0518  , df_denom=36, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3556  , p=0.2734  , df_denom=33, df_num=3
# ssr based chi2 test:   chi2=4.9295  , p=0.1770  , df=3
# likelihood ratio test: chi2=4.6486  , p=0.1994  , df=3
# parameter F test:         F=1.3556  , p=0.2734  , df_denom=33, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0110  , p=0.4174  , df_denom=30, df_num=4
# ssr based chi2 test:   chi2=5.2571  , p=0.2619  , df=4
# likelihood ratio test: chi2=4.9317  , p=0.2944  , df=4
# parameter F test:         F=1.0110  , p=0.4174  , df_denom=30, df_num=4

# %%
#five columns for testing
newdata = newdata[['Pulses_and_Products', 'Housing', 'Health', 'Fuel', 'Clothing']]
print(newdata.shape)
# Out:
# (43, 5)

# %%
#Converting to the('float')type
newdata['Pulses_and_Products'] = newdata['Pulses_and_Products'].astype(float, errors = 'raise')
newdata['Housing'] = newdata['Housing'].astype(float, errors = 'raise')
newdata['Health'] = newdata['Health'].astype(float, errors = 'raise')
newdata['Fuel'] = newdata['Fuel'].astype(float, errors = 'raise')
newdata['Clothing'] = newdata['Clothing'].astype(float, errors = 'raise')

# %%
#split data in training and testing 
train_df = newdata[:-12]
test_df = newdata[-12:]#last 12 values in the testing part
print(test_df.shape)
# Out:
# (12, 5)

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (31, 5)
# (12, 5)

# %%
#Number of Lag consideration
model = VAR(train_df.diff()[1:])
sorted = model.select_order(maxlags=4)
print(sorted.summary())
# Out:
#  VAR Order Selection (* highlights the minimums)
# =================================================
#       AIC         BIC         FPE         HQIC
# -------------------------------------------------
# 0       10.21       10.45   2.711e+04       10.28
# 1       10.19       11.64   2.767e+04       10.60
# 2       10.72       13.38   6.030e+04       11.49
# 3       10.67       14.54   1.200e+05       11.79
# 4      5.241*      10.32*      4306.*      6.704*
# -------------------------------------------------

# %%
#Fitting to model
var_model = VARMAX(train_df, order=(4,0), enforce_stationarity= True)
fitted_model = var_model.fit(disp=False)
print(fitted_model.summary())
# Out:
#                                                   Statespace Model Results
# ============================================================================================================================
# Dep. Variable:     ['Pulses_and_Products', 'Housing', 'Health', 'Fuel', 'Clothing']   No. Observations:                   31
# Model:                                                                       VAR(4)   Log Likelihood                -396.535
#                                                                         + intercept   AIC                           1033.070
# Date:                                                              Mon, 18 Apr 2022   BIC                           1205.149
# Time:                                                                      23:06:28   HQIC                          1089.163
# Sample:                                                                  01-01-2013
#                                                                        - 07-01-2015
# Covariance Type:                                                                opg
# =============================================================================================================
# Ljung-Box (L1) (Q):     0.43, 3.17, 0.76, 9.01, 12.63   Jarque-Bera (JB):    118.93, 14.31, 15.43, 0.58, 3.96
# Prob(Q):                 0.51, 0.08, 0.38, 0.00, 0.00   Prob(JB):                0.00, 0.00, 0.00, 0.75, 0.14
# Heteroskedasticity (H):  4.65, 2.68, 5.51, 2.16, 0.92   Skew:               -2.15, -1.51, -1.35, -0.10, -0.82
# Prob(H) (two-sided):     0.02, 0.14, 0.01, 0.24, 0.90   Kurtosis:               11.58, 4.41, 5.15, 2.36, 3.64
#                          Results for equation Pulses_and_Products
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# intercept                338.7164      0.001   3.63e+05      0.000     338.715     338.718
# L1.Pulses_and_Products     1.4178      0.076     18.567      0.000       1.268       1.567
# L1.Housing                 0.4236      0.113      3.761      0.000       0.203       0.644
# L1.Health                  3.0452      0.074     41.339      0.000       2.901       3.190
# L1.Fuel                   -2.0425      0.100    -20.397      0.000      -2.239      -1.846
# L1.Clothing               -2.7275      0.094    -28.878      0.000      -2.913      -2.542
# L2.Pulses_and_Products     0.6252      0.146      4.291      0.000       0.340       0.911
# L2.Housing                -0.0597      0.231     -0.259      0.796      -0.512       0.392
# L2.Health                  1.4583      0.076     19.181      0.000       1.309       1.607
# L2.Fuel                   -1.2646      0.087    -14.534      0.000      -1.435      -1.094
# L2.Clothing               -0.7064      0.062    -11.326      0.000      -0.829      -0.584
# L3.Pulses_and_Products    -1.1084      0.092    -12.104      0.000      -1.288      -0.929
# L3.Housing                -0.0209      0.137     -0.152      0.879      -0.290       0.248
# L3.Health                  0.6200      0.066      9.357      0.000       0.490       0.750
# L3.Fuel                   -0.6223      0.089     -6.982      0.000      -0.797      -0.448
# L3.Clothing                1.0907      0.052     20.805      0.000       0.988       1.193
# L4.Pulses_and_Products    -0.9464      0.108     -8.766      0.000      -1.158      -0.735
# L4.Housing                -0.0753      0.139     -0.543      0.587      -0.347       0.196
# L4.Health                  2.4114      0.072     33.356      0.000       2.270       2.553
# L4.Fuel                   -3.9161      0.131    -29.869      0.000      -4.173      -3.659
# L4.Clothing                2.4689      0.073     33.745      0.000       2.326       2.612
#                                Results for equation Housing
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# intercept                335.8596      0.001   5.43e+05      0.000     335.858     335.861
# L1.Pulses_and_Products     0.3735      0.098      3.801      0.000       0.181       0.566
# L1.Housing                 0.1634      0.117      1.392      0.164      -0.067       0.394
# L1.Health                  2.8528      0.052     54.763      0.000       2.751       2.955
# L1.Fuel                   -0.9258      0.147     -6.283      0.000      -1.215      -0.637
# L1.Clothing               -2.3355      0.069    -33.711      0.000      -2.471      -2.200
# L2.Pulses_and_Products     0.3523      0.152      2.325      0.020       0.055       0.649
# L2.Housing                 0.2255      0.132      1.705      0.088      -0.034       0.485
# L2.Health                  1.8453      0.078     23.560      0.000       1.692       1.999
# L2.Fuel                   -1.7265      0.127    -13.578      0.000      -1.976      -1.477
# L2.Clothing               -0.6442      0.078     -8.210      0.000      -0.798      -0.490
# L3.Pulses_and_Products    -0.9267      0.200     -4.634      0.000      -1.319      -0.535
# L3.Housing                -0.1734      0.104     -1.660      0.097      -0.378       0.031
# L3.Health                  0.9691      0.065     14.838      0.000       0.841       1.097
# L3.Fuel                   -1.0538      0.074    -14.298      0.000      -1.198      -0.909
# L3.Clothing                1.1442      0.095     12.052      0.000       0.958       1.330
# L4.Pulses_and_Products    -0.9925      0.120     -8.291      0.000      -1.227      -0.758
# L4.Housing                -0.0643      0.127     -0.505      0.613      -0.314       0.185
# L4.Health                  2.7569      0.053     52.296      0.000       2.654       2.860
# L4.Fuel                   -3.3622      0.151    -22.218      0.000      -3.659      -3.066
# L4.Clothing                1.6229      0.125     12.945      0.000       1.377       1.869
#                                Results for equation Health
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# intercept                330.3016      0.001   2.48e+05      0.000     330.299     330.304
# L1.Pulses_and_Products     0.4306      0.142      3.024      0.002       0.152       0.710
# L1.Housing                 0.2326      0.293      0.795      0.427      -0.341       0.806
# L1.Health                  3.1937      0.137     23.362      0.000       2.926       3.462
# L1.Fuel                   -1.6894      0.116    -14.616      0.000      -1.916      -1.463
# L1.Clothing               -2.0418      0.101    -20.183      0.000      -2.240      -1.844
# L2.Pulses_and_Products     0.1994      0.177      1.128      0.259      -0.147       0.546
# L2.Housing                 0.2562      0.123      2.088      0.037       0.016       0.497
# L2.Health                  2.2740      0.121     18.834      0.000       2.037       2.511
# L2.Fuel                   -2.0742      0.148    -13.983      0.000      -2.365      -1.784
# L2.Clothing               -0.6079      0.100     -6.082      0.000      -0.804      -0.412
# L3.Pulses_and_Products    -0.6631      0.166     -3.986      0.000      -0.989      -0.337
# L3.Housing                -0.0966      0.130     -0.743      0.458      -0.352       0.158
# L3.Health                  0.9166      0.100      9.164      0.000       0.721       1.113
# L3.Fuel                   -1.0238      0.119     -8.572      0.000      -1.258      -0.790
# L3.Clothing                0.8320      0.113      7.346      0.000       0.610       1.054
# L4.Pulses_and_Products    -0.7201      0.202     -3.562      0.000      -1.116      -0.324
# L4.Housing                -0.0908      0.104     -0.870      0.384      -0.295       0.114
# L4.Health                  2.2498      0.146     15.376      0.000       1.963       2.537
# L4.Fuel                   -3.0542      0.121    -25.144      0.000      -3.292      -2.816
# L4.Clothing                1.5794      0.104     15.131      0.000       1.375       1.784
#                                 Results for equation Fuel
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# intercept                334.0668      0.001   4.53e+05      0.000     334.065     334.068
# L1.Pulses_and_Products     0.4140      0.143      2.900      0.004       0.134       0.694
# L1.Housing                 0.1661      0.092      1.799      0.072      -0.015       0.347
# L1.Health                  2.8497      0.129     22.119      0.000       2.597       3.102
# L1.Fuel                   -1.3330      0.196     -6.807      0.000      -1.717      -0.949
# L1.Clothing               -1.9760      0.104    -18.970      0.000      -2.180      -1.772
# L2.Pulses_and_Products     0.2369      0.177      1.342      0.180      -0.109       0.583
# L2.Housing                 0.2297      0.161      1.426      0.154      -0.086       0.545
# L2.Health                  2.0381      0.127     16.049      0.000       1.789       2.287
# L2.Fuel                   -1.8391      0.199     -9.251      0.000      -2.229      -1.449
# L2.Clothing               -0.6237      0.105     -5.960      0.000      -0.829      -0.419
# L3.Pulses_and_Products    -0.6847      0.270     -2.533      0.011      -1.215      -0.155
# L3.Housing                -0.1274      0.137     -0.933      0.351      -0.395       0.140
# L3.Health                  0.9703      0.097      9.964      0.000       0.779       1.161
# L3.Fuel                   -0.9712      0.148     -6.578      0.000      -1.261      -0.682
# L3.Clothing                0.7791      0.123      6.344      0.000       0.538       1.020
# L4.Pulses_and_Products    -0.7680      0.162     -4.733      0.000      -1.086      -0.450
# L4.Housing                -0.0904      0.111     -0.814      0.416      -0.308       0.127
# L4.Health                  2.6189      0.124     21.043      0.000       2.375       2.863
# L4.Fuel                   -3.2469      0.149    -21.722      0.000      -3.540      -2.954
# L4.Clothing                1.4625      0.137     10.665      0.000       1.194       1.731
#                               Results for equation Clothing
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# intercept                346.8015      0.001   3.58e+05      0.000     346.800     346.803
# L1.Pulses_and_Products     0.5488      0.098      5.627      0.000       0.358       0.740
# L1.Housing                 0.1747      0.156      1.120      0.263      -0.131       0.480
# L1.Health                  3.2522      0.087     37.520      0.000       3.082       3.422
# L1.Fuel                   -1.6906      0.091    -18.512      0.000      -1.870      -1.512
# L1.Clothing               -2.1514      0.143    -15.031      0.000      -2.432      -1.871
# L2.Pulses_and_Products     0.1877      0.193      0.971      0.332      -0.191       0.567
# L2.Housing                 0.2729      0.108      2.538      0.011       0.062       0.484
# L2.Health                  2.0666      0.041     50.265      0.000       1.986       2.147
# L2.Fuel                   -2.0879      0.131    -15.890      0.000      -2.345      -1.830
# L2.Clothing               -0.3995      0.100     -3.989      0.000      -0.596      -0.203
# L3.Pulses_and_Products    -0.8059      0.204     -3.950      0.000      -1.206      -0.406
# L3.Housing                -0.0284      0.111     -0.255      0.799      -0.247       0.190
# L3.Health                  0.6623      0.099      6.719      0.000       0.469       0.855
# L3.Fuel                   -1.0716      0.089    -11.991      0.000      -1.247      -0.896
# L3.Clothing                1.1906      0.084     14.171      0.000       1.026       1.355
# L4.Pulses_and_Products    -0.8095      0.123     -6.570      0.000      -1.051      -0.568
# L4.Housing                -0.0639      0.147     -0.434      0.664      -0.352       0.224
# L4.Health                  2.1235      0.097     21.967      0.000       1.934       2.313
# L4.Fuel                   -3.2511      0.120    -26.987      0.000      -3.487      -3.015
# L4.Clothing                1.9471      0.066     29.488      0.000       1.818       2.077
#                                          Error covariance matrix
# =========================================================================================================
#                                             coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# sqrt.var.Pulses_and_Products             21.8163      0.072    303.068      0.000      21.675      21.957
# sqrt.cov.Pulses_and_Products.Housing     21.0224      0.038    553.921      0.000      20.948      21.097
# sqrt.var.Housing                          3.6804      0.072     51.338      0.000       3.540       3.821
# sqrt.cov.Pulses_and_Products.Health      20.3385      0.061    334.324      0.000      20.219      20.458
# sqrt.cov.Housing.Health                   1.7557      0.142     12.347      0.000       1.477       2.034
# sqrt.var.Health                           2.2272      0.087     25.572      0.000       2.057       2.398
# sqrt.cov.Pulses_and_Products.Fuel        20.5969      0.069    298.950      0.000      20.462      20.732
# sqrt.cov.Housing.Fuel                     1.9956      0.111     17.915      0.000       1.777       2.214
# sqrt.cov.Health.Fuel                      1.9201      0.112     17.212      0.000       1.701       2.139
# sqrt.var.Fuel                             1.1031      0.190      5.801      0.000       0.730       1.476
# sqrt.cov.Pulses_and_Products.Clothing    21.5275      0.050    427.072      0.000      21.429      21.626
# sqrt.cov.Housing.Clothing                 1.6003      0.061     26.390      0.000       1.481       1.719
# sqrt.cov.Health.Clothing                  1.8699      0.039     48.143      0.000       1.794       1.946
# sqrt.cov.Fuel.Clothing                    0.1724      0.030      5.671      0.000       0.113       0.232
# sqrt.var.Clothing                         1.8029      0.123     14.707      0.000       1.563       2.043
# =========================================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 9.06e+19. Standard errors may be unstable.

# %%
#Forecasting
n_forecast = 24
predict = fitted_model.get_prediction(start=len(train_df),end=len(train_df) + n_forecast-1)

predictions = predict.predicted_mean
predictions
# Out:
#             Pulses_and_Products     Housing      Health        Fuel  \
# 2015-08-01           394.621039  316.561201  322.882536  324.750725
# 2015-09-01           373.968145  292.114183  306.887327  307.596032
# 2015-10-01           361.725909  280.385366  299.373860  299.752219
# 2015-11-01           350.724558  275.191870  296.382118  296.968450
# 2015-12-01           340.481401  274.923363  295.599931  296.586877
# 2016-01-01           335.833697  282.487239  300.374368  302.282627
# 2016-02-01           330.381060  289.219013  303.981312  306.648967
# 2016-03-01           324.841753  295.886534  306.787072  310.294891
# 2016-04-01           319.419795  301.779728  308.691052  313.000957
# 2016-05-01           313.131300  305.935840  309.062465  314.048811
# 2016-06-01           308.234558  310.126222  309.700020  315.265127
# 2016-07-01           303.603442  313.210547  309.756089  315.731391
# 2016-08-01           299.952700  315.942020  309.843888  316.094312
# 2016-09-01           297.566008  318.607304  310.283124  316.681447
# 2016-10-01           296.426331  321.200822  311.083355  317.508903
# 2016-11-01           296.804029  324.034269  312.491418  318.850478
# 2016-12-01           298.471836  326.892271  314.310908  320.516993
# 2017-01-01           301.336542  329.746925  316.480702  322.467695
# 2017-02-01           305.231136  332.487163  318.881589  324.596346
# 2017-03-01           309.913895  334.954471  321.350191  326.750376
# 2017-04-01           315.182025  337.054634  323.773775  328.829815
# 2017-05-01           320.786057  338.672310  326.019743  330.711929
# 2017-06-01           326.512194  339.750858  328.002062  332.321576
# 2017-07-01           332.163598  340.265816  329.660807  333.609125
#
#               Clothing
# 2015-08-01  343.353620
# 2015-09-01  324.097382
# 2015-10-01  314.300075
# 2015-11-01  308.688809
# 2015-12-01  305.303465
# 2016-01-01  307.964364
# 2016-02-01  309.908833
# 2016-03-01  311.492454
# 2016-04-01  312.599249
# 2016-05-01  312.531139
# 2016-06-01  313.166850
# 2016-07-01  313.548799
# 2016-08-01  314.271326
# 2016-09-01  315.601717
# 2016-10-01  317.496430
# 2016-11-01  320.173593
# 2016-12-01  323.377849
# 2017-01-01  327.001970
# 2017-02-01  330.880757
# 2017-03-01  334.804829
# 2017-04-01  338.620604
# 2017-05-01  342.156173
# 2017-06-01  345.292094
# 2017-07-01  347.940869

# %%
#test data variables vs prediction
test_vs_pred = pd.concat([test_df, predictions], axis=1)

# %%
#plot prediction
test_vs_pred.plot(figsize=(12,5))
# Out:
# <AxesSubplot:>
